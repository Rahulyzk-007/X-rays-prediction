# %%
from tensorflow.keras.layers import Conv2D,Flatten,Dense,MaxPool2D,BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import numpy as np

# %%
train_data_dir=r'/Users/rahul/Downloads/organs/train'
valid_data_dir=r'/Users/rahul/Downloads/organs/test'

# %%
train_datagen=ImageDataGenerator(rescale=1/255.0,
                                    rotation_range=30,
                                    zoom_range=0.4,
                                    horizontal_flip=True)
train_generator=train_datagen.flow_from_directory(train_data_dir,
                                                    batch_size=16,
                                                     class_mode='categorical',
                                                     target_size=(224,224))

classes_name=train_generator.class_indices.keys()
classes_name=list(classes_name)
classes_name
# Out:
# Found 1000 images belonging to 4 classes.
# ['brain', 'chest', 'hand_fracture', 'knee']

# %%
validation_datagen=ImageDataGenerator(rescale=1/255.0)
validation_generator=validation_datagen.flow_from_directory(valid_data_dir,
                                                               batch_size=16,
                                                               class_mode='categorical',
                                                               target_size=(224,224))
# Out:
# Found 119 images belonging to 4 classes.

# %%
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras import models,layers
model=models.Sequential()
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(224,224,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(4,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        36928
#
#  flatten (Flatten)           (None, 173056)            0
#
#  dense (Dense)               (None, 64)                11075648
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 11132228 (42.47 MB)
# Trainable params: 11132228 (42.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
history=model.fit(train_generator,epochs=10,validation_data=validation_generator)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 15s 236ms/step - loss: 0.9741 - accuracy: 0.6930 - val_loss: 0.3450 - val_accuracy: 0.8908
# Epoch 2/10
# 63/63 [==============================] - 15s 238ms/step - loss: 0.1854 - accuracy: 0.9460 - val_loss: 0.0482 - val_accuracy: 0.9916
# Epoch 3/10
# 63/63 [==============================] - 16s 250ms/step - loss: 0.1596 - accuracy: 0.9500 - val_loss: 0.0816 - val_accuracy: 0.9748
# Epoch 4/10
# 63/63 [==============================] - 17s 263ms/step - loss: 0.1092 - accuracy: 0.9650 - val_loss: 0.0478 - val_accuracy: 0.9748
# Epoch 5/10
# 63/63 [==============================] - 17s 274ms/step - loss: 0.1576 - accuracy: 0.9510 - val_loss: 0.3140 - val_accuracy: 0.9076
# Epoch 6/10
# 63/63 [==============================] - 18s 280ms/step - loss: 0.1474 - accuracy: 0.9600 - val_loss: 0.0643 - val_accuracy: 0.9916
# Epoch 7/10
# 63/63 [==============================] - 18s 285ms/step - loss: 0.0645 - accuracy: 0.9790 - val_loss: 0.0564 - val_accuracy: 0.9664
# Epoch 8/10
# 63/63 [==============================] - 18s 290ms/step - loss: 0.0710 - accuracy: 0.9740 - val_loss: 0.4048 - val_accuracy: 0.8992
# Epoch 9/10
# 63/63 [==============================] - 19s 296ms/step - loss: 0.0730 - accuracy: 0.9780 - val_loss: 0.1048 - val_accuracy: 0.9664
# Epoch 10/10
# 63/63 [==============================] - 19s 302ms/step - loss: 0.0480 - accuracy: 0.9830 - val_loss: 0.0417 - val_accuracy: 0.9916

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(len(acc))
fig=plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r',label='Training Accuracy')
plt.plot(epochs,val_acc,'b',label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2=plt.figure(figsize=(14,7))
plt.plot(epochs,loss,'r',label='Training Loss')
plt.plot(epochs,val_loss,'b',label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation Loss')
plt.legend(loc='upper right')
plt.show()

# %%
#predicting a single input image
import cv2
img=cv2.imread('/Users/rahul/Downloads/organs/test/knee/DoubtfulG1 (452).png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img=cv2.resize(img,(224,224))
print(img.shape)
plt.imshow(img,cmap=plt.cm.binary)

prediction=model.predict(np.array([img])/255)
index=np.argmax(prediction)
print(classes_name[index])
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 0s 19ms/step
# knee

# %%
classes_name=list(classes_name)
(classes_name[1])

# %%
import joblib
joblib.dump(model,'/Users/rahul/Downloads/brain_tumor_dataset/organ_clissification')
# Out:
# ['/Users/rahul/Downloads/brain_tumor_dataset/organ_clissification']
